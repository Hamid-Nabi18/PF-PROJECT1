# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("sleeptime_prediction_dataset.csv")

# %%
df
# Out:
#       WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 0            1.12         0.52       3.29       7.89          216.08
# 1            2.85         0.49       4.22       5.03          206.18
# 2            2.20         1.81       4.04       9.23           28.73
# 3            1.80         0.50       1.62       7.68          276.77
# 4            0.47         0.54       1.60       4.94          170.54
# ...           ...          ...        ...        ...             ...
# 1995         1.97         0.88       3.74       5.64          257.30
# 1996         2.87         0.67       3.01       5.26          269.25
# 1997         0.21         0.79       4.06       6.73          284.01
# 1998         0.17         1.06       2.94       9.45          119.25
# 1999         0.85         0.32       1.60       4.63           65.14
#
#       RelaxationTime  SleepTime
# 0               0.75       3.45
# 1               0.67       4.88
# 2               0.35       3.61
# ...

# %% [markdown]
# # Data Inspection

# %%
df.head()
# Out:
#    WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 0         1.12         0.52       3.29       7.89          216.08
# 1         2.85         0.49       4.22       5.03          206.18
# 2         2.20         1.81       4.04       9.23           28.73
# 3         1.80         0.50       1.62       7.68          276.77
# 4         0.47         0.54       1.60       4.94          170.54
#
#    RelaxationTime  SleepTime
# 0            0.75       3.45
# 1            0.67       4.88
# 2            0.35       3.61
# 3            1.21       4.94
# 4            0.95       5.50

# %%
df.tail()
# Out:
#       WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 1995         1.97         0.88       3.74       5.64          257.30
# 1996         2.87         0.67       3.01       5.26          269.25
# 1997         0.21         0.79       4.06       6.73          284.01
# 1998         0.17         1.06       2.94       9.45          119.25
# 1999         0.85         0.32       1.60       4.63           65.14
#
#       RelaxationTime  SleepTime
# 1995            0.01       4.24
# 1996            1.75       5.89
# 1997            0.61       3.00
# 1998            1.88       3.53
# 1999            0.63       5.83

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   WorkoutTime     2000 non-null   float64
#  1   ReadingTime     2000 non-null   float64
#  2   PhoneTime       2000 non-null   float64
#  3   WorkHours       2000 non-null   float64
#  4   CaffeineIntake  2000 non-null   float64
#  5   RelaxationTime  2000 non-null   float64
#  6   SleepTime       2000 non-null   float64
# dtypes: float64(7)
# memory usage: 109.5 KB

# %%
df.describe()
# Out:
#        WorkoutTime  ReadingTime    PhoneTime    WorkHours  CaffeineIntake  \
# count  2000.000000  2000.000000  2000.000000  2000.000000     2000.000000
# mean      1.495915     0.992785     2.985195     6.926945      147.493780
# std       0.876639     0.577303     1.151776     1.723843       84.651139
# min       0.010000     0.000000     1.000000     4.000000        0.020000
# 25%       0.710000     0.500000     1.990000     5.440000       75.980000
# 50%       1.520000     0.990000     2.965000     6.910000      146.010000
# 75%       2.250000     1.500000     3.960000     8.422500      218.902500
# max       3.000000     2.000000     5.000000    10.000000      299.850000
#
#        RelaxationTime    SleepTime
# count     2000.000000  2000.000000
# mean         1.010955     4.884375
# std          0.582619     2.028892
# min          0.000000     0.150000
# 25%          0.510000     3.840000
# 50%          1.010000     4.600000
# 75%          1.530000     5.470000
# ...

# %% [markdown]
# # Data Selection

# %%
df.columns
# Out:
# Index(['WorkoutTime', 'ReadingTime', 'PhoneTime', 'WorkHours',
#        'CaffeineIntake', 'RelaxationTime', 'SleepTime'],
#       dtype='object')

# %%
df.dtypes
# Out:
# WorkoutTime       float64
# ReadingTime       float64
# PhoneTime         float64
# WorkHours         float64
# CaffeineIntake    float64
# RelaxationTime    float64
# SleepTime         float64
# dtype: object

# %%
df['WorkHours']
# Out:
# 0       7.89
# 1       5.03
# 2       9.23
# 3       7.68
# 4       4.94
#         ...
# 1995    5.64
# 1996    5.26
# 1997    6.73
# 1998    9.45
# 1999    4.63
# Name: WorkHours, Length: 2000, dtype: float64

# %%
df[['WorkoutTime','ReadingTime']]
# Out:
#       WorkoutTime  ReadingTime
# 0            1.12         0.52
# 1            2.85         0.49
# 2            2.20         1.81
# 3            1.80         0.50
# 4            0.47         0.54
# ...           ...          ...
# 1995         1.97         0.88
# 1996         2.87         0.67
# 1997         0.21         0.79
# 1998         0.17         1.06
# 1999         0.85         0.32
#
# [2000 rows x 2 columns]

# %%
df.loc[0]
# Out:
# WorkoutTime         1.12
# ReadingTime         0.52
# PhoneTime           3.29
# WorkHours           7.89
# CaffeineIntake    216.08
# RelaxationTime      0.75
# SleepTime           3.45
# Name: 0, dtype: float64

# %%
df.iloc[1]
# Out:
# WorkoutTime         2.85
# ReadingTime         0.49
# PhoneTime           4.22
# WorkHours           5.03
# CaffeineIntake    206.18
# RelaxationTime      0.67
# SleepTime           4.88
# Name: 1, dtype: float64

# %%
df.at[0,'WorkoutTime']
# Out:
# 1.12

# %%
df.iat[1,1]
# Out:
# 0.49

# %% [markdown]
# # Data Cleaning

# %%
df.dropna()
# Out:
#       WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 0            1.12         0.52       3.29       7.89          216.08
# 1            2.85         0.49       4.22       5.03          206.18
# 2            2.20         1.81       4.04       9.23           28.73
# 3            1.80         0.50       1.62       7.68          276.77
# 4            0.47         0.54       1.60       4.94          170.54
# ...           ...          ...        ...        ...             ...
# 1995         1.97         0.88       3.74       5.64          257.30
# 1996         2.87         0.67       3.01       5.26          269.25
# 1997         0.21         0.79       4.06       6.73          284.01
# 1998         0.17         1.06       2.94       9.45          119.25
# 1999         0.85         0.32       1.60       4.63           65.14
#
#       RelaxationTime  SleepTime
# 0               0.75       3.45
# 1               0.67       4.88
# 2               0.35       3.61
# ...

# %%
df.fillna(9)
# Out:
#       WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 0            1.12         0.52       3.29       7.89          216.08
# 1            2.85         0.49       4.22       5.03          206.18
# 2            2.20         1.81       4.04       9.23           28.73
# 3            1.80         0.50       1.62       7.68          276.77
# 4            0.47         0.54       1.60       4.94          170.54
# ...           ...          ...        ...        ...             ...
# 1995         1.97         0.88       3.74       5.64          257.30
# 1996         2.87         0.67       3.01       5.26          269.25
# 1997         0.21         0.79       4.06       6.73          284.01
# 1998         0.17         1.06       2.94       9.45          119.25
# 1999         0.85         0.32       1.60       4.63           65.14
#
#       RelaxationTime  SleepTime
# 0               0.75       3.45
# 1               0.67       4.88
# 2               0.35       3.61
# ...

# %%
df.isnull()
# Out:
#       WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 0           False        False      False      False           False
# 1           False        False      False      False           False
# 2           False        False      False      False           False
# 3           False        False      False      False           False
# 4           False        False      False      False           False
# ...           ...          ...        ...        ...             ...
# 1995        False        False      False      False           False
# 1996        False        False      False      False           False
# 1997        False        False      False      False           False
# 1998        False        False      False      False           False
# 1999        False        False      False      False           False
#
#       RelaxationTime  SleepTime
# 0              False      False
# 1              False      False
# 2              False      False
# ...

# %%
df.notnull()
# Out:
#       WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 0            True         True       True       True            True
# 1            True         True       True       True            True
# 2            True         True       True       True            True
# 3            True         True       True       True            True
# 4            True         True       True       True            True
# ...           ...          ...        ...        ...             ...
# 1995         True         True       True       True            True
# 1996         True         True       True       True            True
# 1997         True         True       True       True            True
# 1998         True         True       True       True            True
# 1999         True         True       True       True            True
#
#       RelaxationTime  SleepTime
# 0               True       True
# 1               True       True
# 2               True       True
# ...

# %%
df.rename(columns={'WorkHours':'Work_Hours'})
# Out:
#       WorkoutTime  ReadingTime  PhoneTime  Work_Hours  CaffeineIntake  \
# 0            1.12         0.52       3.29        7.89          216.08
# 1            2.85         0.49       4.22        5.03          206.18
# 2            2.20         1.81       4.04        9.23           28.73
# 3            1.80         0.50       1.62        7.68          276.77
# 4            0.47         0.54       1.60        4.94          170.54
# ...           ...          ...        ...         ...             ...
# 1995         1.97         0.88       3.74        5.64          257.30
# 1996         2.87         0.67       3.01        5.26          269.25
# 1997         0.21         0.79       4.06        6.73          284.01
# 1998         0.17         1.06       2.94        9.45          119.25
# 1999         0.85         0.32       1.60        4.63           65.14
#
#       RelaxationTime  SleepTime
# 0               0.75       3.45
# 1               0.67       4.88
# ...

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Length: 2000, dtype: bool

# %%
df.drop_duplicates()
# Out:
#       WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 0            1.12         0.52       3.29       7.89          216.08
# 1            2.85         0.49       4.22       5.03          206.18
# 2            2.20         1.81       4.04       9.23           28.73
# 3            1.80         0.50       1.62       7.68          276.77
# 4            0.47         0.54       1.60       4.94          170.54
# ...           ...          ...        ...        ...             ...
# 1995         1.97         0.88       3.74       5.64          257.30
# 1996         2.87         0.67       3.01       5.26          269.25
# 1997         0.21         0.79       4.06       6.73          284.01
# 1998         0.17         1.06       2.94       9.45          119.25
# 1999         0.85         0.32       1.60       4.63           65.14
#
#       RelaxationTime  SleepTime
# 0               0.75       3.45
# 1               0.67       4.88
# 2               0.35       3.61
# ...

# %% [markdown]
# # Data Transformation

# %%
df.apply(lambda x: x*2)
# Out:
#       WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 0            2.24         1.04       6.58      15.78          432.16
# 1            5.70         0.98       8.44      10.06          412.36
# 2            4.40         3.62       8.08      18.46           57.46
# 3            3.60         1.00       3.24      15.36          553.54
# 4            0.94         1.08       3.20       9.88          341.08
# ...           ...          ...        ...        ...             ...
# 1995         3.94         1.76       7.48      11.28          514.60
# 1996         5.74         1.34       6.02      10.52          538.50
# 1997         0.42         1.58       8.12      13.46          568.02
# 1998         0.34         2.12       5.88      18.90          238.50
# 1999         1.70         0.64       3.20       9.26          130.28
#
#       RelaxationTime  SleepTime
# 0               1.50       6.90
# 1               1.34       9.76
# 2               0.70       7.22
# ...

# %%
df.replace(1,100)
# Out:
#       WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 0            1.12         0.52       3.29       7.89          216.08
# 1            2.85         0.49       4.22       5.03          206.18
# 2            2.20         1.81       4.04       9.23           28.73
# 3            1.80         0.50       1.62       7.68          276.77
# 4            0.47         0.54       1.60       4.94          170.54
# ...           ...          ...        ...        ...             ...
# 1995         1.97         0.88       3.74       5.64          257.30
# 1996         2.87         0.67       3.01       5.26          269.25
# 1997         0.21         0.79       4.06       6.73          284.01
# 1998         0.17         1.06       2.94       9.45          119.25
# 1999         0.85         0.32       1.60       4.63           65.14
#
#       RelaxationTime  SleepTime
# 0               0.75       3.45
# 1               0.67       4.88
# 2               0.35       3.61
# ...

# %%
df.map(lambda x: x*5)
# Out:
#       WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 0            5.60         2.60      16.45      39.45         1080.40
# 1           14.25         2.45      21.10      25.15         1030.90
# 2           11.00         9.05      20.20      46.15          143.65
# 3            9.00         2.50       8.10      38.40         1383.85
# 4            2.35         2.70       8.00      24.70          852.70
# ...           ...          ...        ...        ...             ...
# 1995         9.85         4.40      18.70      28.20         1286.50
# 1996        14.35         3.35      15.05      26.30         1346.25
# 1997         1.05         3.95      20.30      33.65         1420.05
# 1998         0.85         5.30      14.70      47.25          596.25
# 1999         4.25         1.60       8.00      23.15          325.70
#
#       RelaxationTime  SleepTime
# 0               3.75      17.25
# 1               3.35      24.40
# 2               1.75      18.05
# ...

# %%
df.astype(int)
# Out:
#       WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 0               1            0          3          7             216
# 1               2            0          4          5             206
# 2               2            1          4          9              28
# 3               1            0          1          7             276
# 4               0            0          1          4             170
# ...           ...          ...        ...        ...             ...
# 1995            1            0          3          5             257
# 1996            2            0          3          5             269
# 1997            0            0          4          6             284
# 1998            0            1          2          9             119
# 1999            0            0          1          4              65
#
#       RelaxationTime  SleepTime
# 0                  0          3
# 1                  0          4
# 2                  0          3
# ...

# %% [markdown]
# # Aggregation & Grouping

# %%
df.groupby('WorkHours').sum()
# Out:
#            WorkoutTime  ReadingTime  PhoneTime  CaffeineIntake  \
# WorkHours
# 4.00              5.75         2.27      13.41          676.30
# 4.01              3.55         4.48      11.83          466.15
# 4.02              6.09         3.58       8.38          232.95
# 4.03              0.91         1.87       4.18          214.23
# 4.04              6.60         4.00      11.54          534.79
# ...                ...          ...        ...             ...
# 9.96              2.72         1.62       2.57           37.07
# 9.97              4.85         1.69       5.93          311.11
# 9.98              4.84         3.89       9.14          341.29
# 9.99              4.20         0.89       4.59           83.63
# 10.00             3.01         2.26       7.44          259.45
#
#            RelaxationTime  SleepTime
# WorkHours
# 4.00                 4.98      21.76
# 4.01                 3.93      15.85
# 4.02                 3.18      19.07
# ...

# %%
df.agg(['sum','mean','min','max'])
# Out:
#       WorkoutTime  ReadingTime    PhoneTime     WorkHours  CaffeineIntake  \
# sum   2991.830000  1985.570000  5970.390000  13853.890000    294987.56000
# mean     1.495915     0.992785     2.985195      6.926945       147.49378
# min      0.010000     0.000000     1.000000      4.000000         0.02000
# max      3.000000     2.000000     5.000000     10.000000       299.85000
#
#       RelaxationTime    SleepTime
# sum      2021.910000  9768.750000
# mean        1.010955     4.884375
# min         0.000000     0.150000
# max         2.000000    19.810000

# %%
df.mean()
# Out:
# WorkoutTime         1.495915
# ReadingTime         0.992785
# PhoneTime           2.985195
# WorkHours           6.926945
# CaffeineIntake    147.493780
# RelaxationTime      1.010955
# SleepTime           4.884375
# dtype: float64

# %%
df.max()
# Out:
# WorkoutTime         3.00
# ReadingTime         2.00
# PhoneTime           5.00
# WorkHours          10.00
# CaffeineIntake    299.85
# RelaxationTime      2.00
# SleepTime          19.81
# dtype: float64

# %%
df.min()
# Out:
# WorkoutTime       0.01
# ReadingTime       0.00
# PhoneTime         1.00
# WorkHours         4.00
# CaffeineIntake    0.02
# RelaxationTime    0.00
# SleepTime         0.15
# dtype: float64

# %%
df.sum()
# Out:
# WorkoutTime         2991.83
# ReadingTime         1985.57
# PhoneTime           5970.39
# WorkHours          13853.89
# CaffeineIntake    294987.56
# RelaxationTime      2021.91
# SleepTime           9768.75
# dtype: float64

# %% [markdown]
# # Merging & joining

# %%
pd.merge(df,df,on='WorkHours')
# Out:
#       WorkoutTime_x  ReadingTime_x  PhoneTime_x  WorkHours  CaffeineIntake_x  \
# 0              1.12           0.52         3.29       7.89            216.08
# 1              1.12           0.52         3.29       7.89            216.08
# 2              1.12           0.52         3.29       7.89            216.08
# 3              1.12           0.52         3.29       7.89            216.08
# 4              1.12           0.52         3.29       7.89            216.08
# ...             ...            ...          ...        ...               ...
# 8771           0.17           1.06         2.94       9.45            119.25
# 8772           0.85           0.32         1.60       4.63             65.14
# 8773           0.85           0.32         1.60       4.63             65.14
# 8774           0.85           0.32         1.60       4.63             65.14
# 8775           0.85           0.32         1.60       4.63             65.14
#
# ...

# %%
pd.merge(df,df,on='ReadingTime',how='left')
# Out:
#        WorkoutTime_x  ReadingTime  PhoneTime_x  WorkHours_x  CaffeineIntake_x  \
# 0               1.12         0.52         3.29         7.89            216.08
# 1               1.12         0.52         3.29         7.89            216.08
# 2               1.12         0.52         3.29         7.89            216.08
# 3               1.12         0.52         3.29         7.89            216.08
# 4               1.12         0.52         3.29         7.89            216.08
# ...              ...          ...          ...          ...               ...
# 21849           0.85         0.32         1.60         4.63             65.14
# 21850           0.85         0.32         1.60         4.63             65.14
# 21851           0.85         0.32         1.60         4.63             65.14
# 21852           0.85         0.32         1.60         4.63             65.14
# 21853           0.85         0.32         1.60         4.63             65.14
#
# ...

# %%
pd.concat([df,df])
# Out:
#       WorkoutTime  ReadingTime  PhoneTime  WorkHours  CaffeineIntake  \
# 0            1.12         0.52       3.29       7.89          216.08
# 1            2.85         0.49       4.22       5.03          206.18
# 2            2.20         1.81       4.04       9.23           28.73
# 3            1.80         0.50       1.62       7.68          276.77
# 4            0.47         0.54       1.60       4.94          170.54
# ...           ...          ...        ...        ...             ...
# 1995         1.97         0.88       3.74       5.64          257.30
# 1996         2.87         0.67       3.01       5.26          269.25
# 1997         0.21         0.79       4.06       6.73          284.01
# 1998         0.17         1.06       2.94       9.45          119.25
# 1999         0.85         0.32       1.60       4.63           65.14
#
#       RelaxationTime  SleepTime
# 0               0.75       3.45
# 1               0.67       4.88
# 2               0.35       3.61
# ...

# %% [markdown]
# # Graph Bars

# %%
df["WorkoutTime"].plot(kind='bar', color='black')
# Out:
# <Axes: >

# %%
df["WorkoutTime"].plot(kind='hist',color='red')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["WorkoutTime"].plot(kind='barh',color='green')
# Out:
# <Axes: >

# %%
df["WorkoutTime"].plot(kind='line',color='blue')
# Out:
# <Axes: >

# %%
df["WorkHours"].plot(kind='pie', color='red')
# Out:
# <Axes: ylabel='WorkHours'>
